# %%
# !pip install google-play-scraper==1.2.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Attempting uninstall: google-play-scraper
#     Found existing installation: google-play-scraper 1.2.7
#     Uninstalling google-play-scraper-1.2.7:
#       Successfully uninstalled google-play-scraper-1.2.7
# ...

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
app_id = 'com.tencent.ig'  # PUBG MOBILE package name
count = 10000  # Jumlah ulasan yang diambil
all_reviews = []
continuation_token = None

while len(all_reviews) < count:
    result, continuation_token = reviews(
        app_id,
        lang='en',
        country='us',
        count=500,  # Ambil per batch
        sort=Sort.NEWEST,
        continuation_token=continuation_token
    )
    
    if not result:
        break  # Stop jika tidak ada review lagi
    
    all_reviews.extend(result)
    print(f"Total reviews collected: {len(all_reviews)}")
# Out:
# Total reviews collected: 500
# Total reviews collected: 1000
# Total reviews collected: 1500
# Total reviews collected: 2000
# Total reviews collected: 2500
# Total reviews collected: 3000
# Total reviews collected: 3500
# Total reviews collected: 4000
# Total reviews collected: 4500
# Total reviews collected: 5000
# Total reviews collected: 5500
# Total reviews collected: 6000
# Total reviews collected: 6500
# Total reviews collected: 7000
# Total reviews collected: 7500
# Total reviews collected: 8000
# Total reviews collected: 8500
# Total reviews collected: 9000
# Total reviews collected: 9500
# Total reviews collected: 10000

# %%
df = pd.DataFrame(all_reviews)

# %%
df.head()
# Out:
#                                reviewId           userName  \
# 0  184bc345-a9cc-4422-a9eb-aeaf749c6167  Andreas Djsubekti
# 1  ae27e0d9-c7b0-45e6-a220-ccc2480ce883      noufal ossama
# 2  a34f35eb-64b1-4253-9d95-d9e3ac4a88a6    Saifullah memon
# 3  c21063bd-ce34-4345-b70f-e5e8f0452e48       Isaac Okyere
# 4  6d7a0852-5b7f-4a78-b17b-f125c1dc6a77      panpan panpan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                              content  score  thumbsUpCount  \
# 0                            amazing      5              0
# 1        لاق وتقطيع بدات الي 60 فريم      1              0
# 2                     best game ever      5              0
# ...

# %%
df.tail()
# Out:
#                                   reviewId            userName  \
# 9995  7e5a5161-2da4-4113-b642-cafc48e6f11a         life's good
# 9996  ed30a2a7-bb7c-4146-8770-37fe5c021a35  Nurshiekh Macabuat
# 9997  64bc4dce-c143-4161-8cc9-adca4dd6aafc    adnannicr prince
# 9998  d46c8198-fc92-4fb8-9c5d-d131994ac5db    Md imran Hossine
# 9999  68ebab3a-5521-461b-b1a7-58705c59a768        Mohamed Badr
#
#                                               userImage  \
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 9995  In this new version, when I walk all the thing...      1            257
# 9996  I was playing this game since I was an element...      5              1
# ...

# %%
df.describe()
# Out:
#               score  thumbsUpCount                          at  \
# count  10000.000000   10000.000000                       10000
# mean       4.689900       1.348700  2025-03-23 07:29:20.766400
# min        1.000000       0.000000         2025-03-20 05:35:19
# 25%        5.000000       0.000000         2025-03-21 19:42:39
# 50%        5.000000       0.000000         2025-03-23 00:09:27
# 75%        5.000000       0.000000  2025-03-24 21:21:19.500000
# max        5.000000    2488.000000         2025-03-25 20:51:06
# std        0.941927      42.676106                         NaN
#
#                            repliedAt
# count                            631
# mean   2025-01-15 10:55:53.866877952
# min              2019-11-05 11:43:27
# 25%              2025-03-21 10:55:47
# 50%              2025-03-22 12:17:18
# 75%       2025-03-24 15:50:17.500000
# max              2025-03-26 08:40:31
# std                              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              10000 non-null  object
#  1   userName              10000 non-null  object
#  2   userImage             10000 non-null  object
#  3   content               10000 non-null  object
#  4   score                 10000 non-null  int64
#  5   thumbsUpCount         10000 non-null  int64
#  6   reviewCreatedVersion  7763 non-null   object
#  7   at                    10000 non-null  datetime64[ns]
#  8   replyContent          631 non-null    object
#  9   repliedAt             631 non-null    datetime64[ns]
#  10  appVersion            7763 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 859.5+ KB

# %%
# Simpan ke CSV
df[['userName', 'score', 'content', 'at']].to_csv("pubg_reviews.csv", index=False)
